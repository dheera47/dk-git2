# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# used n as 3, but in the ResNet v1 defination below. we maintained 18 convolutional layers 
# Made ResNet18
n = 3

version = 1

depth = n * 6

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-3
    elif epoch > 40:
        lr *= 1e-3
    elif epoch > 30:
        lr *= 1e-2
    elif epoch > 15:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    if (depth) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            if not (stack > 0 and res_block == 0):
                y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 32, 32, 16)   448         input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 32, 32, 16)   64          conv2d_210[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 32, 32, 16)   0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 32, 32, 16)   2320        activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 32, 32, 16)   64          conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 32, 32, 16)   0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 32, 32, 16)   2320        activation_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 32, 32, 16)   64          conv2d_212[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 32, 32, 16)   0           activation_203[0][0]
#                                                                  batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 32, 32, 16)   0           add_97[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 32, 32, 16)   2320        activation_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 32, 32, 16)   64          conv2d_213[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 32, 32, 16)   0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 32, 32, 16)   2320        activation_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 32, 32, 16)   64          conv2d_214[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 32, 32, 16)   0           activation_205[0][0]
#                                                                  batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 32, 32, 16)   0           add_98[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 32, 32, 16)   2320        activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 32, 32, 16)   64          conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 32, 32, 16)   0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 32, 32, 16)   2320        activation_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 32, 32, 16)   64          conv2d_216[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 32, 32, 16)   0           activation_207[0][0]
#                                                                  batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 32, 32, 16)   0           add_99[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 16, 16, 32)   4640        activation_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 16, 16, 32)   128         conv2d_217[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 16, 16, 32)   544         activation_209[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 16, 16, 32)   0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 16, 16, 32)   0           conv2d_218[0][0]
#                                                                  activation_210[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 16, 16, 32)   0           add_100[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 16, 16, 32)   9248        activation_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 16, 16, 32)   128         conv2d_219[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 16, 16, 32)   0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 16, 16, 32)   9248        activation_212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 16, 16, 32)   128         conv2d_220[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 16, 16, 32)   0           activation_211[0][0]
#                                                                  batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 16, 16, 32)   0           add_101[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 16, 16, 32)   9248        activation_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 16, 16, 32)   128         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 16, 16, 32)   0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 16, 16, 32)   9248        activation_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 16, 16, 32)   128         conv2d_222[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 16, 16, 32)   0           activation_213[0][0]
#                                                                  batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 16, 16, 32)   0           add_102[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 8, 8, 64)     18496       activation_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 8, 8, 64)     256         conv2d_223[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 8, 8, 64)     2112        activation_215[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 8, 8, 64)     0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 8, 8, 64)     0           conv2d_224[0][0]
#                                                                  activation_216[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 8, 8, 64)     0           add_103[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 8, 8, 64)     36928       activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 8, 8, 64)     256         conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 8, 8, 64)     0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 8, 8, 64)     36928       activation_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 8, 8, 64)     256         conv2d_226[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 8, 8, 64)     0           activation_217[0][0]
#                                                                  batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 8, 8, 64)     0           add_104[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 8, 8, 64)     36928       activation_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 8, 8, 64)     256         conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 8, 8, 64)     0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 8, 8, 64)     36928       activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 8, 8, 64)     256         conv2d_228[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 8, 8, 64)     0           activation_219[0][0]
#                                                                  batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 8, 8, 64)     0           add_105[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 1, 1, 64)     0           activation_221[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 64)           0           average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           650         flatten_9[0][0]
# ==================================================================================================
# Total params: 227,882
# Trainable params: 226,698
# Non-trainable params: 1,184
# __________________________________________________________________________________________________
# ResNet18v1
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.6391 - acc: 0.4539 - val_loss: 2.1776 - val_acc: 0.4127
#
# Epoch 00001: val_acc improved from -inf to 0.41270, saving model to /content/saved_models/cifar10_ResNet18v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 1.2271 - acc: 0.6132 - val_loss: 1.1837 - val_acc: 0.6294
#
# Epoch 00002: val_acc improved from 0.41270 to 0.62940, saving model to /content/saved_models/cifar10_ResNet18v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 1.0438 - acc: 0.6827 - val_loss: 1.0626 - val_acc: 0.6764
#
# Epoch 00003: val_acc improved from 0.62940 to 0.67640, saving model to /content/saved_models/cifar10_ResNet18v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.9373 - acc: 0.7271 - val_loss: 1.0232 - val_acc: 0.6934
#
# Epoch 00004: val_acc improved from 0.67640 to 0.69340, saving model to /content/saved_models/cifar10_ResNet18v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.8733 - acc: 0.7485 - val_loss: 1.2761 - val_acc: 0.6501
#
# Epoch 00005: val_acc did not improve from 0.69340
# Epoch 6/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.8215 - acc: 0.7679 - val_loss: 1.1570 - val_acc: 0.6862
#
# Epoch 00006: val_acc did not improve from 0.69340
# Epoch 7/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.7857 - acc: 0.7822 - val_loss: 0.9697 - val_acc: 0.7207
#
# Epoch 00007: val_acc improved from 0.69340 to 0.72070, saving model to /content/saved_models/cifar10_ResNet18v1_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.7567 - acc: 0.7950 - val_loss: 1.3461 - val_acc: 0.6510
#
# Epoch 00008: val_acc did not improve from 0.72070
# Epoch 9/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.7306 - acc: 0.8029 - val_loss: 0.8636 - val_acc: 0.7694
#
# Epoch 00009: val_acc improved from 0.72070 to 0.76940, saving model to /content/saved_models/cifar10_ResNet18v1_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.7138 - acc: 0.8115 - val_loss: 0.9072 - val_acc: 0.7529
#
# Epoch 00010: val_acc did not improve from 0.76940
# Epoch 11/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6949 - acc: 0.8190 - val_loss: 0.8554 - val_acc: 0.7733
#
# Epoch 00011: val_acc improved from 0.76940 to 0.77330, saving model to /content/saved_models/cifar10_ResNet18v1_model.011.h5
# Epoch 12/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6790 - acc: 0.8233 - val_loss: 0.8858 - val_acc: 0.7673
#
# Epoch 00012: val_acc did not improve from 0.77330
# Epoch 13/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6632 - acc: 0.8311 - val_loss: 0.8809 - val_acc: 0.7699
#
# Epoch 00013: val_acc did not improve from 0.77330
# Epoch 14/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6556 - acc: 0.8342 - val_loss: 0.8429 - val_acc: 0.7862
#
# Epoch 00014: val_acc improved from 0.77330 to 0.78620, saving model to /content/saved_models/cifar10_ResNet18v1_model.014.h5
# Epoch 15/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.6428 - acc: 0.8366 - val_loss: 0.8548 - val_acc: 0.7728
#
# Epoch 00015: val_acc did not improve from 0.78620
# Epoch 16/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6342 - acc: 0.8424 - val_loss: 0.7337 - val_acc: 0.8108
#
# Epoch 00016: val_acc improved from 0.78620 to 0.81080, saving model to /content/saved_models/cifar10_ResNet18v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.5328 - acc: 0.8761 - val_loss: 0.5709 - val_acc: 0.8664
#
# Epoch 00017: val_acc improved from 0.81080 to 0.86640, saving model to /content/saved_models/cifar10_ResNet18v1_model.017.h5
# Epoch 18/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.5009 - acc: 0.8860 - val_loss: 0.5478 - val_acc: 0.8705
#
# Epoch 00018: val_acc improved from 0.86640 to 0.87050, saving model to /content/saved_models/cifar10_ResNet18v1_model.018.h5
# Epoch 19/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4848 - acc: 0.8920 - val_loss: 0.5423 - val_acc: 0.8728
#
# Epoch 00019: val_acc improved from 0.87050 to 0.87280, saving model to /content/saved_models/cifar10_ResNet18v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4680 - acc: 0.8967 - val_loss: 0.5399 - val_acc: 0.8739
#
# Epoch 00020: val_acc improved from 0.87280 to 0.87390, saving model to /content/saved_models/cifar10_ResNet18v1_model.020.h5
# Epoch 21/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4596 - acc: 0.8981 - val_loss: 0.5301 - val_acc: 0.8750
#
# Epoch 00021: val_acc improved from 0.87390 to 0.87500, saving model to /content/saved_models/cifar10_ResNet18v1_model.021.h5
# Epoch 22/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4493 - acc: 0.9014 - val_loss: 0.5300 - val_acc: 0.8761
#
# Epoch 00022: val_acc improved from 0.87500 to 0.87610, saving model to /content/saved_models/cifar10_ResNet18v1_model.022.h5
# Epoch 23/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4424 - acc: 0.9025 - val_loss: 0.5227 - val_acc: 0.8762
#
# Epoch 00023: val_acc improved from 0.87610 to 0.87620, saving model to /content/saved_models/cifar10_ResNet18v1_model.023.h5
# Epoch 24/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4314 - acc: 0.9042 - val_loss: 0.5429 - val_acc: 0.8715
#
# Epoch 00024: val_acc did not improve from 0.87620
# Epoch 25/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4288 - acc: 0.9055 - val_loss: 0.5267 - val_acc: 0.8770
#
# Epoch 00025: val_acc improved from 0.87620 to 0.87700, saving model to /content/saved_models/cifar10_ResNet18v1_model.025.h5
# Epoch 26/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4226 - acc: 0.9069 - val_loss: 0.5228 - val_acc: 0.8779
#
# Epoch 00026: val_acc improved from 0.87700 to 0.87790, saving model to /content/saved_models/cifar10_ResNet18v1_model.026.h5
# Epoch 27/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4166 - acc: 0.9074 - val_loss: 0.5155 - val_acc: 0.8774
#
# Epoch 00027: val_acc did not improve from 0.87790
# Epoch 28/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4116 - acc: 0.9097 - val_loss: 0.5019 - val_acc: 0.8819
#
# Epoch 00028: val_acc improved from 0.87790 to 0.88190, saving model to /content/saved_models/cifar10_ResNet18v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.4052 - acc: 0.9105 - val_loss: 0.5457 - val_acc: 0.8696
#
# Epoch 00029: val_acc did not improve from 0.88190
# Epoch 30/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.3992 - acc: 0.9122 - val_loss: 0.4977 - val_acc: 0.8831
#
# Epoch 00030: val_acc improved from 0.88190 to 0.88310, saving model to /content/saved_models/cifar10_ResNet18v1_model.030.h5
# Epoch 31/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3909 - acc: 0.9140 - val_loss: 0.4961 - val_acc: 0.8822
#
# Epoch 00031: val_acc did not improve from 0.88310
# Epoch 32/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3771 - acc: 0.9184 - val_loss: 0.4934 - val_acc: 0.8842
#
# Epoch 00032: val_acc improved from 0.88310 to 0.88420, saving model to /content/saved_models/cifar10_ResNet18v1_model.032.h5
# Epoch 33/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3767 - acc: 0.9186 - val_loss: 0.4896 - val_acc: 0.8849
#
# Epoch 00033: val_acc improved from 0.88420 to 0.88490, saving model to /content/saved_models/cifar10_ResNet18v1_model.033.h5
# Epoch 34/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3714 - acc: 0.9208 - val_loss: 0.4914 - val_acc: 0.8843
#
# Epoch 00034: val_acc did not improve from 0.88490
# Epoch 35/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3704 - acc: 0.9221 - val_loss: 0.4935 - val_acc: 0.8847
#
# Epoch 00035: val_acc did not improve from 0.88490
# Epoch 36/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3694 - acc: 0.9218 - val_loss: 0.4888 - val_acc: 0.8845
#
# Epoch 00036: val_acc did not improve from 0.88490
# Epoch 37/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3696 - acc: 0.9219 - val_loss: 0.4872 - val_acc: 0.8859
#
# Epoch 00037: val_acc improved from 0.88490 to 0.88590, saving model to /content/saved_models/cifar10_ResNet18v1_model.037.h5
# Epoch 38/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3660 - acc: 0.9224 - val_loss: 0.4885 - val_acc: 0.8852
#
# Epoch 00038: val_acc did not improve from 0.88590
# Epoch 39/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3671 - acc: 0.9214 - val_loss: 0.4866 - val_acc: 0.8860
#
# Epoch 00039: val_acc improved from 0.88590 to 0.88600, saving model to /content/saved_models/cifar10_ResNet18v1_model.039.h5
# Epoch 40/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3658 - acc: 0.9213 - val_loss: 0.4852 - val_acc: 0.8866
#
# Epoch 00040: val_acc improved from 0.88600 to 0.88660, saving model to /content/saved_models/cifar10_ResNet18v1_model.040.h5
# Epoch 41/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3641 - acc: 0.9236 - val_loss: 0.4891 - val_acc: 0.8835
#
# Epoch 00041: val_acc did not improve from 0.88660
# Epoch 42/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3614 - acc: 0.9240 - val_loss: 0.4882 - val_acc: 0.8845
#
# Epoch 00042: val_acc did not improve from 0.88660
# Epoch 43/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3622 - acc: 0.9246 - val_loss: 0.4881 - val_acc: 0.8854
#
# Epoch 00043: val_acc did not improve from 0.88660
# Epoch 44/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.3605 - acc: 0.9231 - val_loss: 0.4854 - val_acc: 0.8861
#
# Epoch 00044: val_acc did not improve from 0.88660
# Epoch 45/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 51s 32ms/step - loss: 0.3606 - acc: 0.9240 - val_loss: 0.4886 - val_acc: 0.8854
#
# Epoch 00045: val_acc did not improve from 0.88660
# Epoch 46/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 49s 32ms/step - loss: 0.3660 - acc: 0.9223 - val_loss: 0.4857 - val_acc: 0.8860
#
# Epoch 00046: val_acc did not improve from 0.88660
# Epoch 47/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3630 - acc: 0.9234 - val_loss: 0.4850 - val_acc: 0.8860
#
# Epoch 00047: val_acc did not improve from 0.88660
# Epoch 48/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3648 - acc: 0.9224 - val_loss: 0.4853 - val_acc: 0.8856
#
# Epoch 00048: val_acc did not improve from 0.88660
# Epoch 49/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3630 - acc: 0.9223 - val_loss: 0.4860 - val_acc: 0.8853
#
# Epoch 00049: val_acc did not improve from 0.88660
# Epoch 50/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3640 - acc: 0.9220 - val_loss: 0.4872 - val_acc: 0.8852
#
# Epoch 00050: val_acc did not improve from 0.88660
# 10000/10000 [==============================] - 2s 188us/step
# Test loss: 0.4872209840774536
# Test accuracy: 0.8852

# %% [markdown]
# # GRADCAM

# %% [markdown]
# Let's start with a pretrained VGG model

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
from skimage import io
from google.colab.patches import cv2_imshow
model = VGG16(weights="imagenet")

pic = io.imread("https://www.elsetge.cat/myimg/f/43-437595_kajal-ke-wallpaper-full-hd-kajal-aggarwal.jpg")
pic = cv2.resize(pic, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = image.img_to_array(pic)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
preds = model.predict(x)
class_idx = np.argmax(preds[0])
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("block5_conv3")

grads = K.gradients(class_output, last_conv_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
heatmap = np.mean(conv_layer_output_value, axis = -1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
heatmap = cv2.resize(heatmap, (dog.shape[1], dog.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(dog, 0.5, heatmap, 0.5, 0)

cv2_imshow(pic)
cv2_imshow(superimposed_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b5515ccea4f3> in <module>()
#      17 last_conv_layer = model.get_layer("block5_conv3")
#      18
# ---> 19 grads = K.gradients(class_output, last_conv_layer.output)[0]
#      20 pooled_grads = K.mean(grads, axis=(0, 1, 2))
#      21 iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
#
# NameError: name 'K' is not defined
